# %% [markdown]
# # Global Configuration Settings
# This notebook defines shared paths and configuration variables used across all project notebooks.

# %%
# Base path inside Unity Catalog Volume
base_path = "/Volumes/workspace/beauty/data"

# Curated data paths
curated_customers_path = f"{base_path}/curated/customers"
curated_products_path = f"{base_path}/curated/products"
curated_orders_path = f"{base_path}/curated/orders"
curated_order_items_path = f"{base_path}/curated/order_items"

# Warehouse output
warehouse_sales_path = f"{base_path}/warehouse/fact_sales"

print("Configuration loaded successfully.")
